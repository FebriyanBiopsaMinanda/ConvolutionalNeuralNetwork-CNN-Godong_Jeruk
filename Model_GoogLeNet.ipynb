# %%
import tensorflow as tf
from tensorflow import keras
from tensorflow.keras import backend as K
from tensorflow.keras.layers import Dense, Activation,Dropout,Conv2D, MaxPooling2D,BatchNormalization, Flatten,Input
from tensorflow.keras.optimizers import Adam, Adamax
from tensorflow.keras.metrics import categorical_crossentropy
from tensorflow.keras import regularizers
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from tensorflow.keras.models import Model, load_model, Sequential
from keras.callbacks import ModelCheckpoint
import numpy as np
import pandas as pd
from sklearn.model_selection import train_test_split
import matplotlib.pyplot as plt
from matplotlib.pyplot import imshow
import os
import seaborn as sns
sns.set_style('darkgrid')
from sklearn.metrics import confusion_matrix, classification_report
from IPython.display import display, HTML

# %%
sdir = 'Citrus Leaf Disease Image'

# %%
filepaths = []
labels = []

classlist=os.listdir(sdir)
for klass in classlist:
    classpath=os.path.join(sdir,klass)
    if os.path.isdir(classpath):
        flist=os.listdir(classpath)
        for f in flist:
            fpath=os.path.join(classpath,f)
            filepaths.append(fpath)
            labels.append(klass)
Fseries= pd.Series(filepaths, name='filepaths')
Lseries=pd.Series(labels, name='labels')
df=pd.concat([Fseries, Lseries], axis=1)
print (df.head())
print (df['labels'].value_counts())
# Out:
#                                            filepaths      labels
# 0  Citrus Leaf Disease Image\Black spot\Image (1)...  Black spot
# 1  Citrus Leaf Disease Image\Black spot\Image (10...  Black spot
# 2  Citrus Leaf Disease Image\Black spot\Image (10...  Black spot
# 3  Citrus Leaf Disease Image\Black spot\Image (10...  Black spot
# 4  Citrus Leaf Disease Image\Black spot\Image (10...  Black spot
# Greening      204
# Black spot    169
# Canker        163
# Healthy        58
# Name: labels, dtype: int64

# %%
train_split = 0.8
test_split = 0.1
dummy_split=test_split/(1-train_split)
train_df, dummy_df=train_test_split(df, train_size=train_split, shuffle=True, random_state=123)
test_df, valid_df=train_test_split(dummy_df, train_size=dummy_split, shuffle=True, random_state=123)
print ('train_df length: ', len(train_df), '  test_df length: ', len(test_df), '  valid_df length: ', len(valid_df))
# Out:
# train_df length:  475   test_df length:  59   valid_df length:  60

# %%
height=128
width=128
channels=3
batch_size=64

img_shape=(height, width, channels)
img_size=(height, width)
length=len(test_df)
test_batch_size=sorted([int(length/n) for n in range(1,length+1) if length % n ==0 and length/n<=80],reverse=True)[0]
test_steps=int(length/test_batch_size)
print ( 'test batch size: ' ,test_batch_size, '  test steps: ', test_steps)

gen=ImageDataGenerator(
      rescale=1./255,
      rotation_range=15,
      width_shift_range=0.1,
      height_shift_range=0.1,
      shear_range=0.2,
      zoom_range=0.2,
      horizontal_flip=True,
      fill_mode='nearest'
    )
train_gen=gen.flow_from_dataframe( train_df, x_col='filepaths', y_col='labels', target_size=img_size, class_mode='categorical',
                                    color_mode='rgb', shuffle=True, batch_size=batch_size)

validgen=ImageDataGenerator(
    rescale=1./255
)
valid_gen=validgen.flow_from_dataframe( valid_df, x_col='filepaths', y_col='labels', target_size=img_size, class_mode='categorical',
                                    color_mode='rgb', shuffle=True, batch_size=batch_size)

testgen=ImageDataGenerator(
    rescale=1./255
)
test_gen=testgen.flow_from_dataframe( test_df, x_col='filepaths', y_col='labels', target_size=img_size, class_mode='categorical',
                                    color_mode='rgb', shuffle=False, batch_size=test_batch_size)

classes=list(train_gen.class_indices.keys())
print (classes)
class_count=len(classes)
# Out:
# test batch size:  59   test steps:  1
# Found 475 validated image filenames belonging to 4 classes.
# Found 60 validated image filenames belonging to 4 classes.
# Found 59 validated image filenames belonging to 4 classes.
# ['Black spot', 'Canker', 'Greening', 'Healthy']

# %%
def show_image_samples(gen):
    test_dict=test_gen.class_indices
    classes=list(test_dict.keys())
    images,labels=next(gen) # get a sample batch from the generator
    plt.figure(figsize=(20, 20))
    length=len(labels)
    if length<25:   #show maximum of 25 images
        r=length
    else:
        r=25
    for i in range(r):
        plt.subplot(5, 5, i + 1)
        image=images[i]
        plt.imshow(image)
        index=np.argmax(labels[i])
        class_name=classes[index]
        plt.title(class_name, color='blue', fontsize=16)
        plt.axis('off')
    plt.show()

# %%
show_image_samples(train_gen)

# %%
model_name='Alexnet'

model = tf.keras.models.Sequential([
    tf.keras.layers.Conv2D(64, kernel_size=(3,3), strides= 4, padding= 'valid', activation= 'relu', input_shape= (128, 128, 3), kernel_initializer= 'he_normal'),
    tf.keras.layers.MaxPooling2D(pool_size=(3,3), strides= (2,2), padding= 'valid', data_format= None),
    tf.keras.layers.Conv2D(32, kernel_size=(3,3), strides= 1, padding= 'same', activation= 'relu',kernel_initializer= 'he_normal'),
    tf.keras.layers.MaxPooling2D(pool_size=(3,3), strides= (2,2), padding= 'valid', data_format= None),
    tf.keras.layers.Conv2D(32, kernel_size=(3,3), strides= 1, padding= 'same', activation= 'relu',kernel_initializer= 'he_normal'),    
    tf.keras.layers.Conv2D(32, kernel_size=(3,3), strides= 1, padding= 'same', activation= 'relu',kernel_initializer= 'he_normal'),
    tf.keras.layers.Conv2D(32, kernel_size=(3,3), strides= 1, padding= 'same', activation= 'relu',kernel_initializer= 'he_normal'),
    tf.keras.layers.MaxPooling2D(pool_size=(3,3), strides= (2,2), padding= 'valid', data_format= None),
    tf.keras.layers.Flatten(),
    tf.keras.layers.Dense(16, activation= 'relu'),
    tf.keras.layers.Dense(16, activation= 'relu'),
    tf.keras.layers.Dense(16, activation= 'relu'),
    tf.keras.layers.Dense(class_count, activation= 'softmax')
])


# model = tf.keras.models.Sequential([
#     tf.keras.layers.Conv2D(filters=32, kernel_size=3, strides=1, activation='relu', input_shape=(128,128,3)),
#     tf.keras.layers.BatchNormalization(),
#     tf.keras.layers.MaxPool2D(pool_size=2, strides=2),
#     tf.keras.layers.Conv2D(filters=32, kernel_size=3, strides=1, activation='relu'),
#     tf.keras.layers.BatchNormalization(),
#     tf.keras.layers.MaxPool2D(pool_size=2, strides=2),
#     tf.keras.layers.Conv2D(filters=32, kernel_size=3, strides=1, activation='relu'),
#     tf.keras.layers.BatchNormalization(),
#     tf.keras.layers.MaxPool2D(pool_size=2, strides=2),
#     tf.keras.layers.Conv2D(filters=32, kernel_size=3, strides=1, activation='relu'),
#     tf.keras.layers.BatchNormalization(),
#     tf.keras.layers.MaxPool2D(pool_size=2, strides=2),
#     tf.keras.layers.Flatten(),
    
#     tf.keras.layers.Dropout(0.5),
#     tf.keras.layers.Dense(class_count, activation='softmax')
# ])

model.compile(optimizer=tf.keras.optimizers.Adam(learning_rate=.001), loss='categorical_crossentropy', metrics='accuracy')

# %%
model.summary()
# Out:
# Model: "sequential_6"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv2d_29 (Conv2D)          (None, 32, 32, 64)        1792
#
#  max_pooling2d_19 (MaxPooli  (None, 15, 15, 64)        0
#  ng2D)
#
#  conv2d_30 (Conv2D)          (None, 15, 15, 32)        18464
#
#  max_pooling2d_20 (MaxPooli  (None, 7, 7, 32)          0
#  ng2D)
#
#  conv2d_31 (Conv2D)          (None, 7, 7, 32)          9248
#
#  conv2d_32 (Conv2D)          (None, 7, 7, 32)          9248
#
#  conv2d_33 (Conv2D)          (None, 7, 7, 32)          9248
#
#  max_pooling2d_21 (MaxPooli  (None, 3, 3, 32)          0
#  ng2D)
#
#  flatten_6 (Flatten)         (None, 288)               0
#
#  dense_18 (Dense)            (None, 16)                4624
#
#  dense_19 (Dense)            (None, 16)                272
#
#  dense_20 (Dense)            (None, 16)                272
#
#  dense_21 (Dense)            (None, 4)                 68
#
# =================================================================
# Total params: 53236 (207.95 KB)
# Trainable params: 53236 (207.95 KB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________

# %%
epochs = 100

history=model.fit(x=train_gen, epochs=epochs, validation_data=valid_gen)
# Out:
# Epoch 1/100
# 8/8 [==============================] - 4s 339ms/step - loss: 1.3322 - accuracy: 0.3200 - val_loss: 1.2591 - val_accuracy: 0.3333
# Epoch 2/100
# 8/8 [==============================] - 2s 291ms/step - loss: 1.2373 - accuracy: 0.4126 - val_loss: 1.1628 - val_accuracy: 0.4000
# Epoch 3/100
# 8/8 [==============================] - 2s 290ms/step - loss: 1.1811 - accuracy: 0.4463 - val_loss: 1.1029 - val_accuracy: 0.4333
# Epoch 4/100
# 8/8 [==============================] - 2s 292ms/step - loss: 1.1320 - accuracy: 0.4674 - val_loss: 1.1633 - val_accuracy: 0.4333
# Epoch 5/100
# 8/8 [==============================] - 2s 282ms/step - loss: 1.1373 - accuracy: 0.4526 - val_loss: 1.0594 - val_accuracy: 0.4333
# Epoch 6/100
# 8/8 [==============================] - 2s 289ms/step - loss: 1.0656 - accuracy: 0.4632 - val_loss: 0.9684 - val_accuracy: 0.4833
# Epoch 7/100
# 8/8 [==============================] - 2s 279ms/step - loss: 0.9934 - accuracy: 0.4989 - val_loss: 0.9526 - val_accuracy: 0.5000
# Epoch 8/100
# 8/8 [==============================] - 2s 277ms/step - loss: 1.0153 - accuracy: 0.4821 - val_loss: 0.8779 - val_accuracy: 0.5333
# Epoch 9/100
# 8/8 [==============================] - 2s 286ms/step - loss: 0.9501 - accuracy: 0.5411 - val_loss: 0.9272 - val_accuracy: 0.4167
# Epoch 10/100
# 8/8 [==============================] - 2s 286ms/step - loss: 0.9588 - accuracy: 0.5347 - val_loss: 0.8065 - val_accuracy: 0.5667
# Epoch 11/100
# 8/8 [==============================] - 2s 309ms/step - loss: 0.9902 - accuracy: 0.5116 - val_loss: 0.9455 - val_accuracy: 0.4500
# Epoch 12/100
# 8/8 [==============================] - 2s 286ms/step - loss: 0.9925 - accuracy: 0.4926 - val_loss: 0.9234 - val_accuracy: 0.4500
# Epoch 13/100
# 8/8 [==============================] - 2s 290ms/step - loss: 0.9275 - accuracy: 0.5368 - val_loss: 0.8186 - val_accuracy: 0.5667
# Epoch 14/100
# 8/8 [==============================] - 2s 286ms/step - loss: 0.8786 - accuracy: 0.5621 - val_loss: 0.7729 - val_accuracy: 0.5833
# Epoch 15/100
# 8/8 [==============================] - 2s 280ms/step - loss: 0.8225 - accuracy: 0.5895 - val_loss: 0.7387 - val_accuracy: 0.6000
# Epoch 16/100
# 8/8 [==============================] - 2s 292ms/step - loss: 0.7889 - accuracy: 0.6084 - val_loss: 0.6864 - val_accuracy: 0.6167
# Epoch 17/100
# 8/8 [==============================] - 2s 308ms/step - loss: 0.7601 - accuracy: 0.6063 - val_loss: 0.6865 - val_accuracy: 0.6333
# Epoch 18/100
# 8/8 [==============================] - 2s 292ms/step - loss: 0.7337 - accuracy: 0.6211 - val_loss: 0.6500 - val_accuracy: 0.6500
# Epoch 19/100
# 8/8 [==============================] - 2s 300ms/step - loss: 0.7083 - accuracy: 0.6463 - val_loss: 0.6179 - val_accuracy: 0.7000
# Epoch 20/100
# 8/8 [==============================] - 2s 298ms/step - loss: 0.6969 - accuracy: 0.6568 - val_loss: 0.5918 - val_accuracy: 0.7000
# Epoch 21/100
# 8/8 [==============================] - 2s 288ms/step - loss: 0.6538 - accuracy: 0.6968 - val_loss: 0.5859 - val_accuracy: 0.7167
# Epoch 22/100
# 8/8 [==============================] - 2s 295ms/step - loss: 0.6627 - accuracy: 0.7032 - val_loss: 0.5550 - val_accuracy: 0.7667
# Epoch 23/100
# 8/8 [==============================] - 2s 292ms/step - loss: 0.6505 - accuracy: 0.7011 - val_loss: 0.6114 - val_accuracy: 0.7667
# Epoch 24/100
# 8/8 [==============================] - 2s 287ms/step - loss: 0.6134 - accuracy: 0.7537 - val_loss: 0.5899 - val_accuracy: 0.7167
# Epoch 25/100
# 8/8 [==============================] - 2s 285ms/step - loss: 0.6436 - accuracy: 0.6779 - val_loss: 0.5909 - val_accuracy: 0.7667
# Epoch 26/100
# 8/8 [==============================] - 2s 292ms/step - loss: 0.6522 - accuracy: 0.7011 - val_loss: 0.7861 - val_accuracy: 0.5333
# Epoch 27/100
# 8/8 [==============================] - 2s 295ms/step - loss: 0.6587 - accuracy: 0.6863 - val_loss: 0.6793 - val_accuracy: 0.6167
# Epoch 28/100
# 8/8 [==============================] - 2s 305ms/step - loss: 0.6773 - accuracy: 0.6863 - val_loss: 0.5755 - val_accuracy: 0.7333
# Epoch 29/100
# 8/8 [==============================] - 2s 285ms/step - loss: 0.6980 - accuracy: 0.6758 - val_loss: 0.6156 - val_accuracy: 0.6833
# Epoch 30/100
# 8/8 [==============================] - 2s 292ms/step - loss: 0.5863 - accuracy: 0.7368 - val_loss: 0.6001 - val_accuracy: 0.7000
# Epoch 31/100
# 8/8 [==============================] - 2s 317ms/step - loss: 0.5184 - accuracy: 0.7537 - val_loss: 0.5159 - val_accuracy: 0.7500
# Epoch 32/100
# 8/8 [==============================] - 3s 394ms/step - loss: 0.4801 - accuracy: 0.7958 - val_loss: 0.5074 - val_accuracy: 0.7333
# Epoch 33/100
# 8/8 [==============================] - 3s 385ms/step - loss: 0.4604 - accuracy: 0.7895 - val_loss: 0.7483 - val_accuracy: 0.6500
# Epoch 34/100
# 8/8 [==============================] - 2s 304ms/step - loss: 0.5080 - accuracy: 0.7789 - val_loss: 0.4370 - val_accuracy: 0.8000
# Epoch 35/100
# 8/8 [==============================] - 2s 306ms/step - loss: 0.4387 - accuracy: 0.8358 - val_loss: 0.8013 - val_accuracy: 0.6167
# Epoch 36/100
# 8/8 [==============================] - 2s 329ms/step - loss: 0.5788 - accuracy: 0.7537 - val_loss: 0.5016 - val_accuracy: 0.7500
# Epoch 37/100
# 8/8 [==============================] - 2s 305ms/step - loss: 0.4715 - accuracy: 0.7979 - val_loss: 0.4137 - val_accuracy: 0.8167
# Epoch 38/100
# 8/8 [==============================] - 2s 303ms/step - loss: 0.4134 - accuracy: 0.8337 - val_loss: 0.4621 - val_accuracy: 0.7667
# Epoch 39/100
# 8/8 [==============================] - 2s 300ms/step - loss: 0.3881 - accuracy: 0.8379 - val_loss: 0.4047 - val_accuracy: 0.8000
# Epoch 40/100
# 8/8 [==============================] - 2s 307ms/step - loss: 0.3841 - accuracy: 0.8632 - val_loss: 0.4122 - val_accuracy: 0.8000
# Epoch 41/100
# 8/8 [==============================] - 2s 303ms/step - loss: 0.3440 - accuracy: 0.8716 - val_loss: 0.3690 - val_accuracy: 0.8500
# Epoch 42/100
# 8/8 [==============================] - 2s 305ms/step - loss: 0.3877 - accuracy: 0.8442 - val_loss: 0.3817 - val_accuracy: 0.8000
# Epoch 43/100
# 8/8 [==============================] - 2s 299ms/step - loss: 0.3660 - accuracy: 0.8589 - val_loss: 0.3950 - val_accuracy: 0.8333
# Epoch 44/100
# 8/8 [==============================] - 3s 338ms/step - loss: 0.3959 - accuracy: 0.8442 - val_loss: 0.3672 - val_accuracy: 0.8500
# Epoch 45/100
# 8/8 [==============================] - 2s 298ms/step - loss: 0.3421 - accuracy: 0.8737 - val_loss: 0.3716 - val_accuracy: 0.8667
# Epoch 46/100
# 8/8 [==============================] - 2s 293ms/step - loss: 0.3010 - accuracy: 0.8758 - val_loss: 0.3506 - val_accuracy: 0.8667
# Epoch 47/100
# 8/8 [==============================] - 3s 308ms/step - loss: 0.2988 - accuracy: 0.8800 - val_loss: 0.3744 - val_accuracy: 0.8500
# Epoch 48/100
# 8/8 [==============================] - 2s 304ms/step - loss: 0.3981 - accuracy: 0.8337 - val_loss: 0.4643 - val_accuracy: 0.8333
# Epoch 49/100
# 8/8 [==============================] - 2s 302ms/step - loss: 0.4713 - accuracy: 0.7958 - val_loss: 0.4309 - val_accuracy: 0.8000
# Epoch 50/100
# 8/8 [==============================] - 2s 303ms/step - loss: 0.3835 - accuracy: 0.8547 - val_loss: 0.3119 - val_accuracy: 0.8667
# Epoch 51/100
# 8/8 [==============================] - 2s 301ms/step - loss: 0.3509 - accuracy: 0.8568 - val_loss: 0.3704 - val_accuracy: 0.8333
# Epoch 52/100
# 8/8 [==============================] - 3s 306ms/step - loss: 0.2902 - accuracy: 0.8779 - val_loss: 0.3888 - val_accuracy: 0.8333
# Epoch 53/100
# 8/8 [==============================] - 2s 303ms/step - loss: 0.3120 - accuracy: 0.8779 - val_loss: 0.3662 - val_accuracy: 0.8333
# Epoch 54/100
# 8/8 [==============================] - 2s 302ms/step - loss: 0.2634 - accuracy: 0.8989 - val_loss: 0.3331 - val_accuracy: 0.8667
# Epoch 55/100
# 8/8 [==============================] - 3s 314ms/step - loss: 0.2948 - accuracy: 0.8800 - val_loss: 0.6554 - val_accuracy: 0.7500
# Epoch 56/100
# 8/8 [==============================] - 3s 308ms/step - loss: 0.2868 - accuracy: 0.8800 - val_loss: 0.3830 - val_accuracy: 0.8333
# Epoch 57/100
# 8/8 [==============================] - 3s 316ms/step - loss: 0.2747 - accuracy: 0.8800 - val_loss: 0.4379 - val_accuracy: 0.8333
# Epoch 58/100
# 8/8 [==============================] - 3s 347ms/step - loss: 0.2467 - accuracy: 0.8863 - val_loss: 0.3289 - val_accuracy: 0.8667
# Epoch 59/100
# 8/8 [==============================] - 3s 307ms/step - loss: 0.2225 - accuracy: 0.9137 - val_loss: 0.3351 - val_accuracy: 0.8500
# Epoch 60/100
# 8/8 [==============================] - 3s 305ms/step - loss: 0.2219 - accuracy: 0.9116 - val_loss: 0.3045 - val_accuracy: 0.9167
# Epoch 61/100
# 8/8 [==============================] - 2s 302ms/step - loss: 0.2352 - accuracy: 0.9137 - val_loss: 0.3959 - val_accuracy: 0.8667
# Epoch 62/100
# 8/8 [==============================] - 3s 309ms/step - loss: 0.2441 - accuracy: 0.9095 - val_loss: 0.3277 - val_accuracy: 0.8500
# Epoch 63/100
# 8/8 [==============================] - 3s 332ms/step - loss: 0.2364 - accuracy: 0.8989 - val_loss: 0.4627 - val_accuracy: 0.8167
# Epoch 64/100
# 8/8 [==============================] - 3s 320ms/step - loss: 0.2461 - accuracy: 0.9137 - val_loss: 0.5539 - val_accuracy: 0.8000
# Epoch 65/100
# 8/8 [==============================] - 2s 304ms/step - loss: 0.3148 - accuracy: 0.8800 - val_loss: 0.3769 - val_accuracy: 0.8667
# Epoch 66/100
# 8/8 [==============================] - 3s 337ms/step - loss: 0.4042 - accuracy: 0.8442 - val_loss: 0.3395 - val_accuracy: 0.8667
# Epoch 67/100
# 8/8 [==============================] - 2s 306ms/step - loss: 0.3061 - accuracy: 0.9095 - val_loss: 0.3473 - val_accuracy: 0.8667
# Epoch 68/100
# 8/8 [==============================] - 2s 303ms/step - loss: 0.2604 - accuracy: 0.9095 - val_loss: 0.2351 - val_accuracy: 0.9000
# Epoch 69/100
# 8/8 [==============================] - 2s 301ms/step - loss: 0.2392 - accuracy: 0.8989 - val_loss: 0.2447 - val_accuracy: 0.8833
# Epoch 70/100
# 8/8 [==============================] - 2s 307ms/step - loss: 0.2293 - accuracy: 0.9137 - val_loss: 0.2758 - val_accuracy: 0.9167
# Epoch 71/100
# 8/8 [==============================] - 2s 304ms/step - loss: 0.2214 - accuracy: 0.9011 - val_loss: 0.2168 - val_accuracy: 0.9000
# Epoch 72/100
# 8/8 [==============================] - 3s 336ms/step - loss: 0.2044 - accuracy: 0.9368 - val_loss: 0.2372 - val_accuracy: 0.9167
# Epoch 73/100
# 8/8 [==============================] - 2s 301ms/step - loss: 0.1908 - accuracy: 0.9263 - val_loss: 0.3063 - val_accuracy: 0.9167
# Epoch 74/100
# 8/8 [==============================] - 2s 303ms/step - loss: 0.2003 - accuracy: 0.9368 - val_loss: 0.4452 - val_accuracy: 0.8667
# Epoch 75/100
# 8/8 [==============================] - 3s 360ms/step - loss: 0.1838 - accuracy: 0.9326 - val_loss: 0.2742 - val_accuracy: 0.9000
# Epoch 76/100
# 8/8 [==============================] - 2s 304ms/step - loss: 0.2036 - accuracy: 0.9221 - val_loss: 0.2928 - val_accuracy: 0.9000
# Epoch 77/100
# 8/8 [==============================] - 2s 302ms/step - loss: 0.1692 - accuracy: 0.9284 - val_loss: 0.2421 - val_accuracy: 0.9167
# Epoch 78/100
# 8/8 [==============================] - 3s 309ms/step - loss: 0.1546 - accuracy: 0.9516 - val_loss: 0.3070 - val_accuracy: 0.9167
# Epoch 79/100
# 8/8 [==============================] - 2s 304ms/step - loss: 0.1931 - accuracy: 0.9263 - val_loss: 0.3280 - val_accuracy: 0.8667
# Epoch 80/100
# 8/8 [==============================] - 2s 306ms/step - loss: 0.2166 - accuracy: 0.9242 - val_loss: 0.4687 - val_accuracy: 0.8333
# Epoch 81/100
# 8/8 [==============================] - 2s 325ms/step - loss: 0.3737 - accuracy: 0.8421 - val_loss: 0.3193 - val_accuracy: 0.8667
# Epoch 82/100
# 8/8 [==============================] - 3s 309ms/step - loss: 0.2238 - accuracy: 0.9179 - val_loss: 0.3728 - val_accuracy: 0.8500
# Epoch 83/100
# 8/8 [==============================] - 3s 305ms/step - loss: 0.1894 - accuracy: 0.9284 - val_loss: 0.2471 - val_accuracy: 0.9333
# Epoch 84/100
# 8/8 [==============================] - 3s 307ms/step - loss: 0.2428 - accuracy: 0.9053 - val_loss: 0.2267 - val_accuracy: 0.9333
# Epoch 85/100
# 8/8 [==============================] - 2s 302ms/step - loss: 0.1861 - accuracy: 0.9200 - val_loss: 0.1938 - val_accuracy: 0.9333
# Epoch 86/100
# 8/8 [==============================] - 2s 303ms/step - loss: 0.1750 - accuracy: 0.9368 - val_loss: 0.2948 - val_accuracy: 0.8833
# Epoch 87/100
# 8/8 [==============================] - 2s 303ms/step - loss: 0.1812 - accuracy: 0.9411 - val_loss: 0.2232 - val_accuracy: 0.9000
# Epoch 88/100
# 8/8 [==============================] - 3s 341ms/step - loss: 0.1780 - accuracy: 0.9242 - val_loss: 0.1945 - val_accuracy: 0.9167
# Epoch 89/100
# 8/8 [==============================] - 3s 308ms/step - loss: 0.1609 - accuracy: 0.9411 - val_loss: 0.3422 - val_accuracy: 0.9167
# Epoch 90/100
# 8/8 [==============================] - 2s 301ms/step - loss: 0.1690 - accuracy: 0.9411 - val_loss: 0.1925 - val_accuracy: 0.9333
# Epoch 91/100
# 8/8 [==============================] - 3s 304ms/step - loss: 0.1477 - accuracy: 0.9326 - val_loss: 0.3347 - val_accuracy: 0.9000
# Epoch 92/100
# 8/8 [==============================] - 3s 310ms/step - loss: 0.2907 - accuracy: 0.8863 - val_loss: 0.2720 - val_accuracy: 0.9000
# Epoch 93/100
# 8/8 [==============================] - 2s 300ms/step - loss: 0.2740 - accuracy: 0.8989 - val_loss: 0.1973 - val_accuracy: 0.9500
# Epoch 94/100
# 8/8 [==============================] - 3s 376ms/step - loss: 0.1963 - accuracy: 0.9284 - val_loss: 0.3917 - val_accuracy: 0.8500
# Epoch 95/100
# 8/8 [==============================] - 3s 333ms/step - loss: 0.1707 - accuracy: 0.9389 - val_loss: 0.3989 - val_accuracy: 0.8667
# Epoch 96/100
# 8/8 [==============================] - 3s 313ms/step - loss: 0.1541 - accuracy: 0.9474 - val_loss: 0.1946 - val_accuracy: 0.9333
# Epoch 97/100
# 8/8 [==============================] - 3s 311ms/step - loss: 0.1469 - accuracy: 0.9389 - val_loss: 0.1876 - val_accuracy: 0.9167
# Epoch 98/100
# 8/8 [==============================] - 3s 311ms/step - loss: 0.1469 - accuracy: 0.9432 - val_loss: 0.4547 - val_accuracy: 0.8333
# Epoch 99/100
# 8/8 [==============================] - 3s 319ms/step - loss: 0.1435 - accuracy: 0.9516 - val_loss: 0.1938 - val_accuracy: 0.9333
# Epoch 100/100
# 8/8 [==============================] - 3s 327ms/step - loss: 0.1402 - accuracy: 0.9600 - val_loss: 0.1598 - val_accuracy: 0.9333

# %%
def print_in_color(txt_msg,fore_tupple,back_tupple,):
    #prints the text_msg in the foreground color specified by fore_tupple with the background specified by back_tupple
    #text_msg is the text, fore_tupple is foregroud color tupple (r,g,b), back_tupple is background tupple (r,g,b)
    rf,gf,bf=fore_tupple
    rb,gb,bb=back_tupple
    msg='{0}' + txt_msg
    mat='\33[38;2;' + str(rf) +';' + str(gf) + ';' + str(bf) + ';48;2;' + str(rb) + ';' +str(gb) + ';' + str(bb) +'m'
    print(msg .format(mat), flush=True)
    print('\33[0m', flush=True) # returns default print color to back to black
    return

# %%
def tr_plot(tr_data, start_epoch):
    #Plot the training and validation data
    tacc=tr_data.history['accuracy']
    tloss=tr_data.history['loss']
    vacc=tr_data.history['val_accuracy']
    vloss=tr_data.history['val_loss']
    Epoch_count=len(tacc)+ start_epoch
    Epochs=[]
    for i in range (start_epoch ,Epoch_count):
        Epochs.append(i+1)
    index_loss=np.argmin(vloss)#  this is the epoch with the lowest validation loss
    val_lowest=vloss[index_loss]
    index_acc=np.argmax(vacc)
    acc_highest=vacc[index_acc]
    plt.style.use('fivethirtyeight')
    sc_label='best epoch= '+ str(index_loss+1 +start_epoch)
    vc_label='best epoch= '+ str(index_acc + 1+ start_epoch)
    fig,axes=plt.subplots(nrows=1, ncols=2, figsize=(20,8))
    axes[0].plot(Epochs,tloss, 'r', label='Training loss')
    axes[0].plot(Epochs,vloss,'g',label='Validation loss' )
    axes[0].scatter(index_loss+1 +start_epoch,val_lowest, s=150, c= 'blue', label=sc_label)
    axes[0].set_title('Training and Validation Loss')
    axes[0].set_xlabel('Epochs')
    axes[0].set_ylabel('Loss')
    axes[0].legend()
    axes[1].plot (Epochs,tacc,'r',label= 'Training Accuracy')
    axes[1].plot (Epochs,vacc,'g',label= 'Validation Accuracy')
    axes[1].scatter(index_acc+1 +start_epoch,acc_highest, s=150, c= 'blue', label=vc_label)
    axes[1].set_title('Training and Validation Accuracy')
    axes[1].set_xlabel('Epochs')
    axes[1].set_ylabel('Accuracy')
    axes[1].legend()
    plt.tight_layout
    #plt.style.use('fivethirtyeight')
    plt.show()

# %%
def print_info( test_gen, preds, print_code, save_dir, subject ):
    class_dict=test_gen.class_indices
    labels= test_gen.labels
    file_names= test_gen.filenames
    error_list=[]
    true_class=[]
    pred_class=[]
    prob_list=[]
    new_dict={}
    error_indices=[]
    y_pred=[]
    for key,value in class_dict.items():
        new_dict[value]=key             # dictionary {integer of class number: string of class name}
    # store new_dict as a text fine in the save_dir
    classes=list(new_dict.values())     # list of string of class names
    dict_as_text=str(new_dict)
    dict_name= subject + '-' +str(len(classes)) +'.txt'
    dict_path=os.path.join(save_dir,dict_name)
    with open(dict_path, 'w') as x_file:
        x_file.write(dict_as_text)
    errors=0
    for i, p in enumerate(preds):
        pred_index=np.argmax(p)
        true_index=labels[i]  # labels are integer values
        if pred_index != true_index: # a misclassification has occurred
            error_list.append(file_names[i])
            true_class.append(new_dict[true_index])
            pred_class.append(new_dict[pred_index])
            prob_list.append(p[pred_index])
            error_indices.append(true_index)
            errors=errors + 1
        y_pred.append(pred_index)
    if print_code !=0:
        if errors>0:
            if print_code>errors:
                r=errors
            else:
                r=print_code
            msg='{0:^28s}{1:^28s}{2:^28s}{3:^16s}'.format('Filename', 'Predicted Class' , 'True Class', 'Probability')
            print_in_color(msg, (0,255,0),(55,65,80))
            for i in range(r):
                split1=os.path.split(error_list[i])
                split2=os.path.split(split1[0])
                fname=split2[1] + '/' + split1[1]
                msg='{0:^28s}{1:^28s}{2:^28s}{3:4s}{4:^6.4f}'.format(fname, pred_class[i],true_class[i], ' ', prob_list[i])
                print_in_color(msg, (255,255,255), (55,65,60))
                #print(error_list[i]  , pred_class[i], true_class[i], prob_list[i])
        else:
            msg='With accuracy of 100 % there are no errors to print'
            print_in_color(msg, (0,255,0),(55,65,80))
    if errors>0:
        plot_bar=[]
        plot_class=[]
        for  key, value in new_dict.items():
            count=error_indices.count(key)
            if count!=0:
                plot_bar.append(count) # list containg how many times a class c had an error
                plot_class.append(value)   # stores the class
        fig=plt.figure()
        fig.set_figheight(len(plot_class)/3)
        fig.set_figwidth(10)
        plt.style.use('fivethirtyeight')
        for i in range(0, len(plot_class)):
            c=plot_class[i]
            x=plot_bar[i]
            plt.barh(c, x, )
            plt.title( ' Errors by Class on Test Set')
    y_true= np.array(labels)
    y_pred=np.array(y_pred)
    if len(classes)<= 30:
        # create a confusion matrix
        cm = confusion_matrix(y_true, y_pred )
        length=len(classes)
        if length<8:
            fig_width=8
            fig_height=8
        else:
            fig_width= int(length * .5)
            fig_height= int(length * .5)
        plt.figure(figsize=(fig_width, fig_height))
        sns.heatmap(cm, annot=True, vmin=0, fmt='g', cmap='Blues', cbar=False)
        plt.xticks(np.arange(length)+.5, classes, rotation= 90)
        plt.yticks(np.arange(length)+.5, classes, rotation=0)
        plt.xlabel("Predicted")
        plt.ylabel("Actual")
        plt.title("Confusion Matrix")
        plt.show()
    clr = classification_report(y_true, y_pred, target_names=classes)
    print("Classification Report:\n----------------------\n", clr)

# %%
tr_plot(history,0)
save_dir=r'./'
subject='pest'
acc=model.evaluate( test_gen, batch_size=test_batch_size, verbose=1, steps=test_steps, return_dict=False)[1]*100
msg=f'accuracy on the test set is {acc:5.2f} %'
print_in_color(msg, (0,255,0),(55,65,80))
save_id=str (model_name + '.h5')
save_loc=os.path.join(save_dir, save_id)
model.save(save_loc)
# Out:
# 1/1 [==============================] - 0s 228ms/step - loss: 0.0702 - accuracy: 0.9661
# accuracy on the test set is 96.61 %
# c:\Users\ACER\AppData\Local\Programs\Python\Python311\Lib\site-packages\keras\src\engine\training.py:3000: UserWarning: You are saving your model as an HDF5 file via `model.save()`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')`.
#   saving_api.save_model(

# %%
print_code=0
preds=model.predict(test_gen)
print_info( test_gen, preds, print_code, save_dir, subject )
# Out:
# 1/1 [==============================] - 0s 306ms/step
# Classification Report:
# ----------------------
#                precision    recall  f1-score   support
#
#   Black spot       0.93      0.93      0.93        14
#       Canker       1.00      1.00      1.00        10
#     Greening       0.96      0.96      0.96        25
#      Healthy       1.00      1.00      1.00        10
#
#     accuracy                           0.97        59
#    macro avg       0.97      0.97      0.97        59
# weighted avg       0.97      0.97      0.97        59
